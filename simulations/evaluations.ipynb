# %%
# Import libraries
import numpy as np
import pandas as pd
import os
import sys
sys.path.append(os.path.abspath('/Users/idrees/Code/govxs/'))
from model.VotingModel import VotingModel
from model.EvalMetrics import EvalMetrics

# Add the directory containing the VotingModel to the Python path

from model.VotingRules import VotingRules

# Initialize simulation parameters
num_voters = 144
num_projects = 600
total_op_tokens = 30e6
num_rounds = 100
voter_type = 'mallows_model'
quorum=17
# Initialize the model
model = VotingModel(voter_type=voter_type, num_voters=num_voters, num_projects=num_projects, total_op_tokens=total_op_tokens)

# Initialize the evaluation metrics
model.step()
eval_metrics = EvalMetrics(model)
output_dir = '/Users/idrees/Code/govxs/data/simulation_data'
allocation_df=model.compile_fund_allocations()
allocation_df.to_csv(os.path.join(output_dir, 'allocation_df.csv'), index=False)
allocation_df
# Out:
# /Users/idrees/Code/govxs/agents/VoterAgent.py:7: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
#     majoritarian_moving_phantoms  r1_quadratic   r2_mean  r3_median  \
# 0                       3.676955      3.225418  3.782116   4.061655
# 1                       1.795107      2.225425  1.903047   1.858399
# 2                       1.593030      2.136605  1.749906   1.426057
# 3                       3.805388      3.127466  3.538144   3.715866
# 4                       1.829703      2.136563  1.688034   1.892505
# 5                       1.362732      1.696768  1.175096   1.192882
# 6                       3.344522      3.044370  3.346945   3.631302
# 7                       2.551843      2.861543  3.118236   2.821730
# 8                       1.445288      1.644624  1.199170   1.073805
# 9                       1.593030      2.008543  1.653572   1.083628
# 10                      5.409373      3.867144  5.335693   5.792277
# 11                      1.593030      2.025531  1.510041   1.449894
#
#     r4_capped_median     Project
# 0           3.825530   Project 1
# 1           2.142215   Project 2
# 2           1.643846   Project 3
# 3           3.769850   Project 4
# 4           2.181530   Project 5
# 5           1.375060   Project 6
# 6           3.825530   Project 7
# 7           3.252667   Project 8
# 8           1.237798   Project 9
# 9           1.249121  Project 10
# 10          3.825530  Project 11
# 11          1.671323  Project 12

# %% [markdown]
# # Evaluate Egalitarian Score

# %%
egalitarian_results=eval_metrics.evaluate_egalitarian_score(num_rounds)
egalitarian_results.to_csv(os.path.join(output_dir, 'egalitarian_results.csv'), index=False)
egalitarian_results
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 egalitarian_results=eval_metrics.evaluate_egalitarian_score(num_rounds)
#       2 egalitarian_results.to_csv(os.path.join(output_dir, 'egalitarian_results.csv'), index=False)
#       3 egalitarian_results
#
# File ~/Code/govxs/model/EvalMetrics.py:402, in EvalMetrics.evaluate_egalitarian_score(self, num_rounds)
#     400 self.model.step()
#     401 for voting_rule in self.model.voting_rules.keys():
# --> 402     allocation = self.model.allocate_funds(voting_rule)
#     403     egalitarian_score = self.calculate_egalitarian_score(allocation, self.model.voting_matrix)
#     404     results[f'{voting_rule}_egalitarian_score'].append(egalitarian_score)
#
# File ~/Code/govxs/model/VotingModel.py:63, in VotingModel.allocate_funds(self, method)
#      61 if method not in self.voting_rules:
#      62     raise ValueError(f"Unknown aggregation method: {method}")
# ---> 63 return self.voting_rules[method](self.voting_matrix, self.total_op_tokens, self.num_voters)
#
# File ~/Code/govxs/model/VotingRules.py:73, in VotingRules.majoritarian_moving_phantoms(self, voting_matrix, total_op_tokens, num_voters)
#      70     return low
#      72 num_voters, m = voting_matrix.shape
# ---> 73 t_star = find_t_star()
#      74 distribution = np.array([median_with_phantoms(t_star, j) for j in range(m)])
#      75 best_distribution = distribution * (total_op_tokens / np.sum(distribution))
#
# File ~/Code/govxs/model/VotingRules.py:66, in VotingRules.majoritarian_moving_phantoms.<locals>.find_t_star()
#      64 while high - low > epsilon:
#      65     mid = (low + high) / 2
# ---> 66     if sum(median_with_phantoms(mid, j) for j in range(m)) > 1:
#      67         high = mid
#      68     else:
#
# File ~/Code/govxs/model/VotingRules.py:66, in <genexpr>(.0)
#      64 while high - low > epsilon:
#      65     mid = (low + high) / 2
# ---> 66     if sum(median_with_phantoms(mid, j) for j in range(m)) > 1:
#      67         high = mid
#      68     else:
#
# File ~/Code/govxs/model/VotingRules.py:58, in VotingRules.majoritarian_moving_phantoms.<locals>.median_with_phantoms(t_star, j)
#      56 def median_with_phantoms(t_star, j):
#      57     phantom_votes = [f_k(t_star, k, num_voters) for k in range(num_voters + 1)]
# ---> 58     real_votes = voting_matrix[:, j] / sum(voting_matrix[0])
#      59     return np.median(phantom_votes + list(real_votes))
#
# KeyboardInterrupt:

# %%
egalitarian_results.describe()
# Out:
#             round  majoritarian_moving_phantoms_egalitarian_score  \
# count  100.000000                                    1.000000e+02
# mean    50.500000                                    2.339490e+07
# std     29.011492                                    2.493186e+05
# min      1.000000                                    2.281475e+07
# 25%     25.750000                                    2.321964e+07
# 50%     50.500000                                    2.338629e+07
# 75%     75.250000                                    2.355262e+07
# max    100.000000                                    2.400175e+07
#
#        r1_quadratic_egalitarian_score  r2_mean_egalitarian_score  \
# count                    1.000000e+02               1.000000e+02
# mean                     2.345827e+07               2.344917e+07
# std                      2.338824e+05               2.399579e+05
# min                      2.295343e+07               2.281935e+07
# 25%                      2.326404e+07               2.328378e+07
# 50%                      2.345425e+07               2.344416e+07
# 75%                      2.363072e+07               2.362559e+07
# max                      2.402635e+07               2.396986e+07
#
#        r3_median_egalitarian_score  r4_capped_median_egalitarian_score
# count                 1.000000e+02                        1.000000e+02
# mean                  2.349314e+07                        2.349314e+07
# std                   2.577597e+05                        2.577597e+05
# min                   2.294059e+07                        2.294059e+07
# 25%                   2.328052e+07                        2.328052e+07
# 50%                   2.349280e+07                        2.349280e+07
# 75%                   2.366336e+07                        2.366336e+07
# max                   2.424128e+07                        2.424128e+07

# %% [markdown]
# # Evaluate Gini Index

# %%
gini_results,allocations = eval_metrics.evaluate_gini_index(num_rounds)
gini_results.to_csv(os.path.join(output_dir, 'gini_results.csv'), index=False)
print("Gini Index Results:")
gini_results.head(100)
# Out:
# Gini Index Results:
#     round  majoritarian_moving_phantoms_gini_index  r1_quadratic_gini_index  \
# 0       1                                 0.064949                 0.027784
# 1       2                                 0.061109                 0.026616
# 2       3                                 0.071789                 0.030621
# 3       4                                 0.066169                 0.028565
# 4       5                                 0.064368                 0.026653
# ..    ...                                      ...                      ...
# 95     96                                 0.065028                 0.027460
# 96     97                                 0.066569                 0.027792
# 97     98                                 0.065820                 0.027489
# 98     99                                 0.065271                 0.026835
# 99    100                                 0.064394                 0.027099
#
#     r2_mean_gini_index  r3_median_gini_index  r4_capped_median_gini_index
# 0             0.053678              0.078826                     0.078826
# 1             0.053054              0.074604                     0.074604
# 2             0.058857              0.084318                     0.084318
# 3             0.056115              0.081052                     0.081052
# 4             0.051320              0.078794                     0.078794
# ..                 ...                   ...                          ...
# 95            0.053376              0.077871                     0.077871
# 96            0.054670              0.080742                     0.080742
# 97            0.054432              0.077525                     0.077525
# 98            0.051503              0.077159                     0.077159
# 99            0.053346              0.080176                     0.080176
#
# [100 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
def plot_lorenz_curve(averaged_cumulative_allocations):
        plt.figure(figsize=(8, 8))
        
        for voting_rule, lorenz_values in averaged_cumulative_allocations.items():
            # Lorenz curve starts at (0,0)
            plt.plot(np.linspace(0, 1, len(lorenz_values)), lorenz_values, label=voting_rule)
        
        # Line of equality
        plt.plot([0, 1], [0, 1], color='black', linestyle='--')
        
        plt.xlabel('Cumulative Population Proportion')
        plt.ylabel('Cumulative Funding Proportion')
        plt.title('Lorenz Curve for Different Voting Rules')
        plt.legend()
        plt.grid(True)
        plt.show()
plot_lorenz_curve(allocations)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Prepare data for box plot
gini_results_long = gini_results.melt(id_vars=['round'], var_name='voting_rule', value_name='gini_index')
gini_results_long['voting_rule'] = gini_results_long['voting_rule'].str.replace('_gini_index', '')

# Box Plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='voting_rule', y='gini_index', data=gini_results_long)
plt.title('Gini Index Distribution by Voting Rule')
plt.xlabel('Voting Rule')
plt.ylabel('Gini Index')
plt.show()

# Line Plot
plt.figure(figsize=(12, 6))
sns.lineplot(x='round', y='gini_index', hue='voting_rule', data=gini_results_long)
plt.title('Gini Index Over Rounds by Voting Rule')
plt.xlabel('Round')
plt.ylabel('Gini Index')
plt.show()

# %% [markdown]
# # Evaluate Alignment with Ground Truth

# %%
alignment_results = eval_metrics.evaluate_alignment(num_rounds)
alignment_results.to_csv(os.path.join(output_dir, 'alignment_results.csv'), index=False)
print("Alignment Results:")
alignment_results.head(100)
# Out:
# Alignment Results:
#     round  majoritarian_moving_phantoms_l1_distance  r1_quadratic_l1_distance  \
# 0       1                              2.957766e+06              1.330536e+06
# 1       2                              2.765213e+06              1.283209e+06
# 2       3                              3.141228e+06              1.332601e+06
# 3       4                              2.685907e+06              1.167559e+06
# 4       5                              2.825401e+06              1.242974e+06
# ..    ...                                       ...                       ...
# 95     96                              2.761947e+06              1.269888e+06
# 96     97                              3.016622e+06              1.308606e+06
# 97     98                              2.853584e+06              1.183450e+06
# 98     99                              2.900167e+06              1.298912e+06
# 99    100                              2.793052e+06              1.263000e+06
#
#     r2_mean_l1_distance  r3_median_l1_distance  r4_capped_median_l1_distance
# 0          2.578689e+06           3.494662e+06                  3.494662e+06
# 1          2.471893e+06           3.483674e+06                  3.483674e+06
# 2          2.499446e+06           3.604614e+06                  3.604614e+06
# 3          2.283254e+06           3.276046e+06                  3.276046e+06
# 4          2.344150e+06           3.476853e+06                  3.476853e+06
# ..                  ...                    ...                           ...
# 95         2.369245e+06           3.372653e+06                  3.372653e+06
# 96         2.485503e+06           3.461325e+06                  3.461325e+06
# 97         2.237045e+06           3.151357e+06                  3.151357e+06
# 98         2.431852e+06           3.549491e+06                  3.549491e+06
# 99         2.393944e+06           3.603204e+06                  3.603204e+06
#
# [100 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Prepare data for plotting
alignment_results_long = alignment_results.melt(id_vars=['round'], var_name='voting_rule', value_name='l1_distance')
alignment_results_long['voting_rule'] = alignment_results_long['voting_rule'].str.replace('_l1_distance', '')

# Box Plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='voting_rule', y='l1_distance', data=alignment_results_long)
plt.title('l1 Distance Distribution by Voting Rule')
plt.xlabel('Voting Rule')
plt.ylabel('l1 Distance')
plt.show()

# Line Plot
plt.figure(figsize=(12, 6))
sns.lineplot(x='round', y='l1_distance', hue='voting_rule', data=alignment_results_long, marker='o')
plt.title('l1 Distance Over Rounds by Voting Rule')
plt.xlabel('Round')
plt.ylabel('l1 Distance')
plt.show()

# %%
def calculate_alignment_metrics(alignment_results):
    metrics = {
        "voting_rule": [],
        "mean_l1_distance": [],
        "std_l1_distance": [],
        "min_l1_distance": [],
        "max_l1_distance": []
    }
    
    for voting_rule in model.voting_rules.keys():
        l1_distances = alignment_results[f"{voting_rule}_l1_distance"]
        metrics["voting_rule"].append(voting_rule)
        metrics["mean_l1_distance"].append(np.mean(l1_distances))
        metrics["std_l1_distance"].append(np.std(l1_distances))
        metrics["min_l1_distance"].append(np.min(l1_distances))
        metrics["max_l1_distance"].append(np.max(l1_distances))
    
    return pd.DataFrame(metrics)

# Calculate metrics
alignment_metrics = calculate_alignment_metrics(alignment_results)

alignment_metrics
# Out:
#                     voting_rule  mean_l1_distance  std_l1_distance  \
# 0  majoritarian_moving_phantoms      2.794142e+06    105270.965566
# 1                  r1_quadratic      1.254727e+06     42644.283051
# 2                       r2_mean      2.390020e+06     81067.668601
# 3                     r3_median      3.414659e+06     93766.945578
# 4              r4_capped_median      3.414659e+06     93766.945578
#
#    min_l1_distance  max_l1_distance
# 0     2.554905e+06     3.141228e+06
# 1     1.167559e+06     1.348932e+06
# 2     2.225813e+06     2.578689e+06
# 3     3.151357e+06     3.646425e+06
# 4     3.151357e+06     3.646425e+06

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting metrics
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Mean l1 Distance
sns.barplot(x='voting_rule', y='mean_l1_distance', data=alignment_metrics, ax=axes[0, 0])
axes[0, 0].set_title('Mean l1 Distance by Voting Rule')
axes[0, 0].set_xlabel('Voting Rule')
axes[0, 0].set_ylabel('Mean l1 Distance')

# Standard Deviation of l1 Distance
sns.barplot(x='voting_rule', y='std_l1_distance', data=alignment_metrics, ax=axes[0, 1])
axes[0, 1].set_title('Standard Deviation of l1 Distance by Voting Rule')
axes[0, 1].set_xlabel('Voting Rule')
axes[0, 1].set_ylabel('Standard Deviation of l1 Distance')

# Minimum l1 Distance
sns.barplot(x='voting_rule', y='min_l1_distance', data=alignment_metrics, ax=axes[1, 0])
axes[1, 0].set_title('Minimum l1 Distance by Voting Rule')
axes[1, 0].set_xlabel('Voting Rule')
axes[1, 0].set_ylabel('Minimum l1 Distance')

# Maximum l1 Distance
sns.barplot(x='voting_rule', y='max_l1_distance', data=alignment_metrics, ax=axes[1, 1])
axes[1, 1].set_title('Maximum l1 Distance by Voting Rule')
axes[1, 1].set_xlabel('Voting Rule')
axes[1, 1].set_ylabel('Maximum l1 Distance')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluate Social Welfare

# %%
social_welfare_results = eval_metrics.evaluate_social_welfare(num_rounds)
social_welfare_results.to_csv(os.path.join(output_dir, 'social_welfare_results.csv'), index=False)
print("Social Welfare Results:")
social_welfare_results.head(100)
# Out:
# Social Welfare Results:
#     round  majoritarian_moving_phantoms_social_welfare_avg_l1_distance  \
# 0       1                                       2.177359e+07
# 1       2                                       2.190856e+07
# 2       3                                       2.189766e+07
# 3       4                                       2.192631e+07
# 4       5                                       2.185919e+07
# ..    ...                                                ...
# 95     96                                       2.178226e+07
# 96     97                                       2.180391e+07
# 97     98                                       2.177856e+07
# 98     99                                       2.184607e+07
# 99    100                                       2.187340e+07
#
#     r1_quadratic_social_welfare_avg_l1_distance  \
# 0                                  2.187186e+07
# 1                                  2.200467e+07
# 2                                  2.199252e+07
# 3                                  2.201583e+07
# 4                                  2.195679e+07
# ..                                          ...
# 95                                 2.188375e+07
# 96                                 2.189888e+07
# 97                                 2.188196e+07
# 98                                 2.194472e+07
# 99                                 2.197264e+07
#
#     r2_mean_social_welfare_avg_l1_distance  \
# 0                             2.185184e+07
# 1                             2.199132e+07
# 2                             2.197396e+07
# 3                             2.200222e+07
# 4                             2.194081e+07
# ..                                     ...
# 95                            2.186285e+07
# 96                            2.188028e+07
# 97                            2.185204e+07
# 98                            2.192691e+07
# 99                            2.195250e+07
#
#     r3_median_social_welfare_avg_l1_distance  \
# 0                               2.186538e+07
# 1                               2.199814e+07
# 2                               2.198712e+07
# 3                               2.202437e+07
# 4                               2.195111e+07
# ..                                       ...
# 95                              2.186975e+07
# 96                              2.189268e+07
# 97                              2.187590e+07
# 98                              2.193424e+07
# 99                              2.197624e+07
#
#     r4_capped_median_social_welfare_avg_l1_distance
# 0                                      2.186538e+07
# 1                                      2.199814e+07
# 2                                      2.198712e+07
# 3                                      2.202437e+07
# 4                                      2.195111e+07
# ..                                              ...
# 95                                     2.186975e+07
# 96                                     2.189268e+07
# 97                                     2.187590e+07
# 98                                     2.193424e+07
# 99                                     2.197624e+07
#
# [100 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Prepare data for plotting
social_welfare_results_long = social_welfare_results.melt(id_vars=['round'], var_name='voting_rule', value_name='social_welfare')
social_welfare_results_long['voting_rule'] = social_welfare_results_long['voting_rule'].str.replace('_social_welfare', '')

# Box Plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='voting_rule', y='social_welfare', data=social_welfare_results_long)
plt.title('Social Welfare Distribution by Voting Rule')
plt.xlabel('Voting Rule')
plt.ylabel('Social Welfare')
plt.show()

# Line Plot
plt.figure(figsize=(12, 6))
sns.lineplot(x='round', y='social_welfare', hue='voting_rule', data=social_welfare_results_long, marker='o')
plt.title('Social Welfare Over Rounds by Voting Rule')
plt.xlabel('Round')
plt.ylabel('Social Welfare')
plt.show()

# %% [markdown]
# # Evaluate Resistance to Control

# %%
control_results_constant_desired_increase = eval_metrics.evaluate_control(num_rounds)
control_results_constant_desired_increase.to_csv(os.path.join(output_dir, 'control_results_constant_desired_increase.csv'), index=False)
print("Control Results:")
control_results_constant_desired_increase.head(100)
# Out:
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 0: 3.540739396221154
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 0: 4.248887275465385
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 1: 1.474875276326497
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 1: 1.7698503315917964
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 2: 2.0514595973599348
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 2: 2.4617515168319217
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 3: 1.8825355750614703
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 3: 2.2590426900737643
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 4: 1.3743156007499764
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 4: 1.6491787208999715
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 5: 1.487047802983381
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 5: 1.7844573635800571
# No voters left in the matrix. Cannot proceed.
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 6: 6.535956708551556
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 6: 7.843148050261867
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 7: 1.412012499085243
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 7: 1.6944149989022914
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 8: 2.550901135094922
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 8: 3.061081362113906
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 9: 1.7359254001466693
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 9: 2.083110480176003
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 10: 2.981046373721753
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 10: 3.5772556484661036
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 11: 2.9731846346974438
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 11: 3.5678215616369324
# Voting Rule: r1_quadratic: Original Funds for Project 0: 3.0671268911251266
# Voting Rule: r1_quadratic: Target Funds for Project 0: 3.6805522693501516
# Voting Rule: r1_quadratic: Original Funds for Project 1: 2.08202640905423
# Voting Rule: r1_quadratic: Target Funds for Project 1: 2.498431690865076
# Voting Rule: r1_quadratic: Original Funds for Project 2: 2.3273486034671795
# Voting Rule: r1_quadratic: Target Funds for Project 2: 2.7928183241606153
# Voting Rule: r1_quadratic: Original Funds for Project 3: 2.034303258340745
# Voting Rule: r1_quadratic: Target Funds for Project 3: 2.441163910008894
# Voting Rule: r1_quadratic: Original Funds for Project 4: 1.7202264220622865
# Voting Rule: r1_quadratic: Target Funds for Project 4: 2.064271706474744
# Voting Rule: r1_quadratic: Original Funds for Project 5: 2.205318556860382
# Voting Rule: r1_quadratic: Target Funds for Project 5: 2.646382268232458
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r1_quadratic: Original Funds for Project 6: 4.309979368733522
# Voting Rule: r1_quadratic: Target Funds for Project 6: 5.171975242480227
# Voting Rule: r1_quadratic: Original Funds for Project 7: 1.8084405326122204
# Voting Rule: r1_quadratic: Target Funds for Project 7: 2.1701286391346644
# Voting Rule: r1_quadratic: Original Funds for Project 8: 2.5950239652657734
# Voting Rule: r1_quadratic: Target Funds for Project 8: 3.114028758318928
# Voting Rule: r1_quadratic: Original Funds for Project 9: 2.0243423289728404
# Voting Rule: r1_quadratic: Target Funds for Project 9: 2.429210794767408
# Voting Rule: r1_quadratic: Original Funds for Project 10: 2.8941392833483035
# Voting Rule: r1_quadratic: Target Funds for Project 10: 3.472967140017964
# Voting Rule: r1_quadratic: Original Funds for Project 11: 2.931724380157397
# Voting Rule: r1_quadratic: Target Funds for Project 11: 3.5180692561888764
# Voting Rule: r2_mean: Original Funds for Project 0: 3.427892414972369
# Voting Rule: r2_mean: Target Funds for Project 0: 4.113470897966843
# Voting Rule: r2_mean: Original Funds for Project 1: 1.8386218022595724
# Voting Rule: r2_mean: Target Funds for Project 1: 2.206346162711487
# Voting Rule: r2_mean: Original Funds for Project 2: 1.9690885543900292
# Voting Rule: r2_mean: Target Funds for Project 2: 2.362906265268035
# Voting Rule: r2_mean: Original Funds for Project 3: 1.6245041290509068
# Voting Rule: r2_mean: Target Funds for Project 3: 1.9494049548610881
# Voting Rule: r2_mean: Original Funds for Project 4: 1.1379560630626726
# Voting Rule: r2_mean: Target Funds for Project 4: 1.3655472756752072
# Voting Rule: r2_mean: Original Funds for Project 5: 1.9027819731809927
# Voting Rule: r2_mean: Target Funds for Project 5: 2.283338367817191
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r2_mean: Original Funds for Project 6: 6.606473697673707
# Voting Rule: r2_mean: Target Funds for Project 6: 7.927768437208448
# Voting Rule: r2_mean: Original Funds for Project 7: 1.2372973146860828
# Voting Rule: r2_mean: Target Funds for Project 7: 1.4847567776232993
# Voting Rule: r2_mean: Original Funds for Project 8: 2.4867034358679536
# Voting Rule: r2_mean: Target Funds for Project 8: 2.9840441230415444
# Voting Rule: r2_mean: Original Funds for Project 9: 1.497411249407297
# Voting Rule: r2_mean: Target Funds for Project 9: 1.7968934992887564
# Voting Rule: r2_mean: Original Funds for Project 10: 3.0936479610633993
# Voting Rule: r2_mean: Target Funds for Project 10: 3.712377553276079
# Voting Rule: r2_mean: Original Funds for Project 11: 3.1776214043850217
# Voting Rule: r2_mean: Target Funds for Project 11: 3.813145685262026
# Voting Rule: r3_median: Original Funds for Project 0: 3.563311517342228
# Voting Rule: r3_median: Target Funds for Project 0: 4.275973820810673
# Voting Rule: r3_median: Original Funds for Project 1: 1.2421057860098859
# Voting Rule: r3_median: Target Funds for Project 1: 1.490526943211863
# Voting Rule: r3_median: Original Funds for Project 2: 2.1589917416500373
# Voting Rule: r3_median: Target Funds for Project 2: 2.5907900899800445
# Voting Rule: r3_median: Original Funds for Project 3: 1.7805761278572223
# Voting Rule: r3_median: Target Funds for Project 3: 2.1366913534286667
# Voting Rule: r3_median: Original Funds for Project 4: 0.9562172286732996
# Voting Rule: r3_median: Target Funds for Project 4: 1.1474606744079594
# Voting Rule: r3_median: Original Funds for Project 5: 1.5304500062065374
# Voting Rule: r3_median: Target Funds for Project 5: 1.8365400074478448
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r3_median: Original Funds for Project 6: 7.17790498504021
# Voting Rule: r3_median: Target Funds for Project 6: 8.613485982048251
# Voting Rule: r3_median: Original Funds for Project 7: 1.2694983782069618
# Voting Rule: r3_median: Target Funds for Project 7: 1.523398053848354
# Voting Rule: r3_median: Original Funds for Project 8: 2.5557754811189657
# Voting Rule: r3_median: Target Funds for Project 8: 3.0669305773427586
# Voting Rule: r3_median: Original Funds for Project 9: 1.6351822931411837
# Voting Rule: r3_median: Target Funds for Project 9: 1.9622187517694203
# Voting Rule: r3_median: Original Funds for Project 10: 3.0023362533431803
# Voting Rule: r3_median: Target Funds for Project 10: 3.602803504011816
# Voting Rule: r3_median: Original Funds for Project 11: 3.1276502014102876
# Voting Rule: r3_median: Target Funds for Project 11: 3.7531802416923448
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 0: 3.791749617611273
# Voting Rule: r4_capped_median: Target Funds for Project 0: 4.550099541133528
# Voting Rule: r4_capped_median: Original Funds for Project 1: 1.4424625585083968
# Voting Rule: r4_capped_median: Target Funds for Project 1: 1.730955070210076
# Voting Rule: r4_capped_median: Original Funds for Project 2: 2.50724599026562
# Voting Rule: r4_capped_median: Target Funds for Project 2: 3.0086951883187436
# Voting Rule: r4_capped_median: Original Funds for Project 3: 2.0677903814123777
# Voting Rule: r4_capped_median: Target Funds for Project 3: 2.4813484576948532
# Voting Rule: r4_capped_median: Original Funds for Project 4: 1.110459000913887
# Voting Rule: r4_capped_median: Target Funds for Project 4: 1.3325508010966645
# Voting Rule: r4_capped_median: Original Funds for Project 5: 1.7773178874832993
# Voting Rule: r4_capped_median: Target Funds for Project 5: 2.132781464979959
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 6: 3.842945888499493
# Voting Rule: r4_capped_median: Target Funds for Project 6: 4.611535066199392
# Voting Rule: r4_capped_median: Original Funds for Project 7: 1.4742736885021643
# Voting Rule: r4_capped_median: Target Funds for Project 7: 1.7691284262025972
# Voting Rule: r4_capped_median: Original Funds for Project 8: 2.9680325790210516
# Voting Rule: r4_capped_median: Target Funds for Project 8: 3.561639094825262
# Voting Rule: r4_capped_median: Original Funds for Project 9: 1.898943923100996
# Voting Rule: r4_capped_median: Target Funds for Project 9: 2.278732707721195
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 10: 3.4866254406655255
# Voting Rule: r4_capped_median: Target Funds for Project 10: 4.18395052879863
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 11: 3.6321530440159133
# Voting Rule: r4_capped_median: Target Funds for Project 11: 4.358583652819096
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 0: 1.1113911865089583
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 0: 1.3336694238107498
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 1: 2.1910782282461962
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 1: 2.6292938738954352
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 2: 4.908305297531007
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 2: 5.889966357037209
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 3: 1.73064133788626
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 3: 2.076769605463512
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 4: 3.729025486462447
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 4: 4.474830583754936
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 5: 1.757570328018058
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 5: 2.109084393621669
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 6: 0.9309318588508244
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 6: 1.1171182306209892
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 7: 1.9468131737924246
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 7: 2.3361758085509092
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 8: 2.387575559639537
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 8: 2.8650906715674442
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 9: 1.8992606556250644
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 9: 2.279112786750077
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 10: 2.7107703432143473
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 10: 3.2529244118572165
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 11: 4.696636544224875
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 11: 5.63596385306985
# Voting Rule: r1_quadratic: Original Funds for Project 0: 1.6720463610481466
# Voting Rule: r1_quadratic: Target Funds for Project 0: 2.006455633257776
# Voting Rule: r1_quadratic: Original Funds for Project 1: 2.3784047425741646
# Voting Rule: r1_quadratic: Target Funds for Project 1: 2.8540856910889976
# Voting Rule: r1_quadratic: Original Funds for Project 2: 3.6701345164610952
# Voting Rule: r1_quadratic: Target Funds for Project 2: 4.404161419753314
# Voting Rule: r1_quadratic: Original Funds for Project 3: 2.085454432081338
# Voting Rule: r1_quadratic: Target Funds for Project 3: 2.5025453184976056
# Voting Rule: r1_quadratic: Original Funds for Project 4: 3.549936052384339
# Voting Rule: r1_quadratic: Target Funds for Project 4: 4.259923262861206
# Voting Rule: r1_quadratic: Original Funds for Project 5: 1.8280601124622646
# Voting Rule: r1_quadratic: Target Funds for Project 5: 2.1936721349547175
# Voting Rule: r1_quadratic: Original Funds for Project 6: 1.6926816104001547
# Voting Rule: r1_quadratic: Target Funds for Project 6: 2.031217932480186
# Voting Rule: r1_quadratic: Original Funds for Project 7: 2.251581217370798
# Voting Rule: r1_quadratic: Target Funds for Project 7: 2.7018974608449575
# Voting Rule: r1_quadratic: Original Funds for Project 8: 2.4910255507327386
# Voting Rule: r1_quadratic: Target Funds for Project 8: 2.989230660879286
# Voting Rule: r1_quadratic: Original Funds for Project 9: 2.0566709731703035
# Voting Rule: r1_quadratic: Target Funds for Project 9: 2.468005167804364
# Voting Rule: r1_quadratic: Original Funds for Project 10: 2.6566914675267026
# Voting Rule: r1_quadratic: Target Funds for Project 10: 3.188029761032043
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r1_quadratic: Original Funds for Project 11: 3.667312963787957
# Voting Rule: r1_quadratic: Target Funds for Project 11: 4.400775556545548
# Voting Rule: r2_mean: Original Funds for Project 0: 1.102631513754511
# Voting Rule: r2_mean: Target Funds for Project 0: 1.3231578165054132
# Voting Rule: r2_mean: Original Funds for Project 1: 2.033306167730827
# Voting Rule: r2_mean: Target Funds for Project 1: 2.4399674012769923
# Voting Rule: r2_mean: Original Funds for Project 2: 4.802870645131478
# Voting Rule: r2_mean: Target Funds for Project 2: 5.763444774157774
# Voting Rule: r2_mean: Original Funds for Project 3: 1.6763333791205555
# Voting Rule: r2_mean: Target Funds for Project 3: 2.0116000549446666
# Voting Rule: r2_mean: Original Funds for Project 4: 4.585216812813243
# Voting Rule: r2_mean: Target Funds for Project 4: 5.502260175375892
# Voting Rule: r2_mean: Original Funds for Project 5: 1.3542952424320114
# Voting Rule: r2_mean: Target Funds for Project 5: 1.6251542909184136
# Voting Rule: r2_mean: Original Funds for Project 6: 1.2683054961290072
# Voting Rule: r2_mean: Target Funds for Project 6: 1.5219665953548087
# Voting Rule: r2_mean: Original Funds for Project 7: 1.832886659694409
# Voting Rule: r2_mean: Target Funds for Project 7: 2.1994639916332908
# Voting Rule: r2_mean: Original Funds for Project 8: 2.3124714032321134
# Voting Rule: r2_mean: Target Funds for Project 8: 2.774965683878536
# Voting Rule: r2_mean: Original Funds for Project 9: 1.586759624500805
# Voting Rule: r2_mean: Target Funds for Project 9: 1.904111549400966
# Voting Rule: r2_mean: Original Funds for Project 10: 2.6909318394109776
# Voting Rule: r2_mean: Target Funds for Project 10: 3.229118207293173
# Voting Rule: r2_mean: Original Funds for Project 11: 4.753991216050061
# Voting Rule: r2_mean: Target Funds for Project 11: 5.7047894592600725
# Voting Rule: r3_median: Original Funds for Project 0: 1.0119819383579882
# Voting Rule: r3_median: Target Funds for Project 0: 1.2143783260295857
# Voting Rule: r3_median: Original Funds for Project 1: 2.189934341587038
# Voting Rule: r3_median: Target Funds for Project 1: 2.627921209904445
# Voting Rule: r3_median: Original Funds for Project 2: 5.2851713130352165
# Voting Rule: r3_median: Target Funds for Project 2: 6.34220557564226
# Voting Rule: r3_median: Original Funds for Project 3: 1.5968634019873569
# Voting Rule: r3_median: Target Funds for Project 3: 1.9162360823848281
# Voting Rule: r3_median: Original Funds for Project 4: 4.054670670751387
# Voting Rule: r3_median: Target Funds for Project 4: 4.865604804901664
# Voting Rule: r3_median: Original Funds for Project 5: 1.7769632820671084
# Voting Rule: r3_median: Target Funds for Project 5: 2.13235593848053
# Voting Rule: r3_median: Original Funds for Project 6: 0.8057921857741847
# Voting Rule: r3_median: Target Funds for Project 6: 0.9669506229290216
# Voting Rule: r3_median: Original Funds for Project 7: 1.9746641096935673
# Voting Rule: r3_median: Target Funds for Project 7: 2.3695969316322807
# Voting Rule: r3_median: Original Funds for Project 8: 2.4200333426035288
# Voting Rule: r3_median: Target Funds for Project 8: 2.9040400111242346
# Voting Rule: r3_median: Original Funds for Project 9: 1.5591901656509288
# Voting Rule: r3_median: Target Funds for Project 9: 1.8710281987811146
# Voting Rule: r3_median: Original Funds for Project 10: 2.2311652831325444
# Voting Rule: r3_median: Target Funds for Project 10: 2.677398339759053
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r3_median: Original Funds for Project 11: 5.093569965359154
# Voting Rule: r3_median: Target Funds for Project 11: 6.112283958430985
# Voting Rule: r4_capped_median: Original Funds for Project 0: 1.1929424533280295
# Voting Rule: r4_capped_median: Target Funds for Project 0: 1.4315309439936355
# Voting Rule: r4_capped_median: Original Funds for Project 1: 2.5815338664235985
# Voting Rule: r4_capped_median: Target Funds for Project 1: 3.097840639708318
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 2: 3.8832756345223403
# Voting Rule: r4_capped_median: Target Funds for Project 2: 4.659930761426808
# Voting Rule: r4_capped_median: Original Funds for Project 3: 1.8824112093220582
# Voting Rule: r4_capped_median: Target Funds for Project 3: 2.2588934511864696
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 4: 3.8832756345223403
# Voting Rule: r4_capped_median: Target Funds for Project 4: 4.659930761426808
# Voting Rule: r4_capped_median: Original Funds for Project 5: 2.0947161770718092
# Voting Rule: r4_capped_median: Target Funds for Project 5: 2.513659412486171
# Voting Rule: r4_capped_median: Original Funds for Project 6: 0.9498822760905489
# Voting Rule: r4_capped_median: Target Funds for Project 6: 1.1398587313086586
# Voting Rule: r4_capped_median: Original Funds for Project 7: 2.3277694573668763
# Voting Rule: r4_capped_median: Target Funds for Project 7: 2.7933233488402514
# Voting Rule: r4_capped_median: Original Funds for Project 8: 2.8527786943958535
# Voting Rule: r4_capped_median: Target Funds for Project 8: 3.423334433275024
# Voting Rule: r4_capped_median: Original Funds for Project 9: 1.838001322864098
# Voting Rule: r4_capped_median: Target Funds for Project 9: 2.2056015874369175
# Voting Rule: r4_capped_median: Original Funds for Project 10: 2.6301376395701124
# Voting Rule: r4_capped_median: Target Funds for Project 10: 3.1561651674841347
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 11: 3.8832756345223403
# Voting Rule: r4_capped_median: Target Funds for Project 11: 4.659930761426808
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 0: 2.517219419776522
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 0: 3.0206633037318262
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 1: 4.0205462005543495
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 1: 4.824655440665219
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 2: 2.129765743791917
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 2: 2.5557188925503
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 3: 1.4520132189474442
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 3: 1.742415862736933
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 4: 4.613399546920849
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 4: 5.536079456305019
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 5: 1.1820249392909377
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 5: 1.4184299271491252
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 6: 2.3233411040118033
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 6: 2.7880093248141637
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 7: 1.5385577928204748
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 7: 1.8462693513845696
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 8: 2.507127257049099
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 8: 3.0085527084589185
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 9: 2.517219419776522
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 9: 3.0206633037318262
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 10: 2.681565937283559
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 10: 3.217879124740271
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 11: 2.517219419776522
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 11: 3.0206633037318262
# Voting Rule: r1_quadratic: Original Funds for Project 0: 2.4901905118648338
# Voting Rule: r1_quadratic: Target Funds for Project 0: 2.9882286142378005
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r1_quadratic: Original Funds for Project 1: 3.314895059413833
# Voting Rule: r1_quadratic: Target Funds for Project 1: 3.977874071296599
# Voting Rule: r1_quadratic: Original Funds for Project 2: 2.3384109838025
# Voting Rule: r1_quadratic: Target Funds for Project 2: 2.806093180563
# Voting Rule: r1_quadratic: Original Funds for Project 3: 2.1128271826225773
# Voting Rule: r1_quadratic: Target Funds for Project 3: 2.5353926191470926
# Voting Rule: r1_quadratic: Original Funds for Project 4: 3.602289350178847
# Voting Rule: r1_quadratic: Target Funds for Project 4: 4.322747220214616
# Voting Rule: r1_quadratic: Original Funds for Project 5: 1.5649880480829599
# Voting Rule: r1_quadratic: Target Funds for Project 5: 1.8779856576995517
# Voting Rule: r1_quadratic: Original Funds for Project 6: 2.565628572356514
# Voting Rule: r1_quadratic: Target Funds for Project 6: 3.0787542868278166
# Voting Rule: r1_quadratic: Original Funds for Project 7: 1.7331458855302935
# Voting Rule: r1_quadratic: Target Funds for Project 7: 2.0797750626363523
# Voting Rule: r1_quadratic: Original Funds for Project 8: 2.57693133735743
# Voting Rule: r1_quadratic: Target Funds for Project 8: 3.092317604828916
# Voting Rule: r1_quadratic: Original Funds for Project 9: 2.1699323268366366
# Voting Rule: r1_quadratic: Target Funds for Project 9: 2.603918792203964
# Voting Rule: r1_quadratic: Original Funds for Project 10: 2.8126991688501977
# Voting Rule: r1_quadratic: Target Funds for Project 10: 3.375239002620237
# Voting Rule: r1_quadratic: Original Funds for Project 11: 2.718061573103375
# Voting Rule: r1_quadratic: Target Funds for Project 11: 3.26167388772405
# Voting Rule: r2_mean: Original Funds for Project 0: 2.358439740221432
# Voting Rule: r2_mean: Target Funds for Project 0: 2.8301276882657183
# Voting Rule: r2_mean: Original Funds for Project 1: 4.0293443602931465
# Voting Rule: r2_mean: Target Funds for Project 1: 4.835213232351776
# Voting Rule: r2_mean: Original Funds for Project 2: 2.122109541160532
# Voting Rule: r2_mean: Target Funds for Project 2: 2.546531449392638
# Voting Rule: r2_mean: Original Funds for Project 3: 1.7305717139826555
# Voting Rule: r2_mean: Target Funds for Project 3: 2.0766860567791867
# Voting Rule: r2_mean: Original Funds for Project 4: 4.756894358085989
# Voting Rule: r2_mean: Target Funds for Project 4: 5.708273229703187
# Voting Rule: r2_mean: Original Funds for Project 5: 1.0536799583542873
# Voting Rule: r2_mean: Target Funds for Project 5: 1.2644159500251446
# Voting Rule: r2_mean: Original Funds for Project 6: 2.5315251230665097
# Voting Rule: r2_mean: Target Funds for Project 6: 3.0378301476798115
# Voting Rule: r2_mean: Original Funds for Project 7: 1.218330919763537
# Voting Rule: r2_mean: Target Funds for Project 7: 1.4619971037162445
# Voting Rule: r2_mean: Original Funds for Project 8: 2.724439329819875
# Voting Rule: r2_mean: Target Funds for Project 8: 3.2693271957838497
# Voting Rule: r2_mean: Original Funds for Project 9: 1.8362891217592487
# Voting Rule: r2_mean: Target Funds for Project 9: 2.2035469461110986
# Voting Rule: r2_mean: Original Funds for Project 10: 2.9268685060960635
# Voting Rule: r2_mean: Target Funds for Project 10: 3.512242207315276
# Voting Rule: r2_mean: Original Funds for Project 11: 2.711507327396721
# Voting Rule: r2_mean: Target Funds for Project 11: 3.253808792876065
# Voting Rule: r3_median: Original Funds for Project 0: 1.9841481092467483
# Voting Rule: r3_median: Target Funds for Project 0: 2.380977731096098
# Voting Rule: r3_median: Original Funds for Project 1: 4.488633592218274
# Voting Rule: r3_median: Target Funds for Project 1: 5.386360310661928
# Voting Rule: r3_median: Original Funds for Project 2: 2.319750199017043
# Voting Rule: r3_median: Target Funds for Project 2: 2.7837002388204515
# Voting Rule: r3_median: Original Funds for Project 3: 1.5521726795541413
# Voting Rule: r3_median: Target Funds for Project 3: 1.8626072154649695
# Voting Rule: r3_median: Original Funds for Project 4: 5.275362923278103
# Voting Rule: r3_median: Target Funds for Project 4: 6.330435507933724
# Voting Rule: r3_median: Original Funds for Project 5: 0.9712464177595347
# Voting Rule: r3_median: Target Funds for Project 5: 1.1654957013114415
# Voting Rule: r3_median: Original Funds for Project 6: 2.3765715519488766
# Voting Rule: r3_median: Target Funds for Project 6: 2.851885862338652
# Voting Rule: r3_median: Original Funds for Project 7: 1.239242943161018
# Voting Rule: r3_median: Target Funds for Project 7: 1.4870915317932214
# Voting Rule: r3_median: Original Funds for Project 8: 1.9061098088889326
# Voting Rule: r3_median: Target Funds for Project 8: 2.287331770666719
# Voting Rule: r3_median: Original Funds for Project 9: 1.9136921582109094
# Voting Rule: r3_median: Target Funds for Project 9: 2.2964305898530912
# Voting Rule: r3_median: Original Funds for Project 10: 3.0942393859495976
# Voting Rule: r3_median: Target Funds for Project 10: 3.713087263139517
# Voting Rule: r3_median: Original Funds for Project 11: 2.878830230766824
# Voting Rule: r3_median: Target Funds for Project 11: 3.454596276920189
# Voting Rule: r4_capped_median: Original Funds for Project 0: 2.186550581197726
# Voting Rule: r4_capped_median: Target Funds for Project 0: 2.623860697437271
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 1: 3.8498633307776804
# Voting Rule: r4_capped_median: Target Funds for Project 1: 4.619835996933216
# Voting Rule: r4_capped_median: Original Funds for Project 2: 2.5563873595201816
# Voting Rule: r4_capped_median: Target Funds for Project 2: 3.0676648314242176
# Voting Rule: r4_capped_median: Original Funds for Project 3: 1.7105094417002886
# Voting Rule: r4_capped_median: Target Funds for Project 3: 2.0526113300403463
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 4: 3.8498633307776804
# Voting Rule: r4_capped_median: Target Funds for Project 4: 4.619835996933216
# Voting Rule: r4_capped_median: Original Funds for Project 5: 1.0703230315021912
# Voting Rule: r4_capped_median: Target Funds for Project 5: 1.2843876378026293
# Voting Rule: r4_capped_median: Original Funds for Project 6: 2.619005045013785
# Voting Rule: r4_capped_median: Target Funds for Project 6: 3.142806054016542
# Voting Rule: r4_capped_median: Original Funds for Project 7: 1.3656578180761856
# Voting Rule: r4_capped_median: Target Funds for Project 7: 1.6387893816914227
# Voting Rule: r4_capped_median: Original Funds for Project 8: 2.100551612568391
# Voting Rule: r4_capped_median: Target Funds for Project 8: 2.520661935082069
# Voting Rule: r4_capped_median: Original Funds for Project 9: 2.1089074355231134
# Voting Rule: r4_capped_median: Target Funds for Project 9: 2.530688922627736
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 10: 3.4098820023478416
# Voting Rule: r4_capped_median: Target Funds for Project 10: 4.09185840281741
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 11: 3.172499010994937
# Voting Rule: r4_capped_median: Target Funds for Project 11: 3.8069988131939243
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 0: 4.471946635619185
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 0: 5.366335962743022
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 1: 2.046191086520614
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 1: 2.455429303824737
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 2: 3.1680322337167874
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 2: 3.8016386804601447
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 3: 2.6410969106252713
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 3: 3.1693162927503256
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 4: 2.1214746514275253
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 4: 2.54576958171303
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 5: 2.031412787457138
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 5: 2.437695344948566
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 6: 2.2244000101061236
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 6: 2.669280012127348
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 7: 1.7926250229592304
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 7: 2.1511500275510764
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 8: 1.239073346647118
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 8: 1.4868880159765416
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 9: 2.6410969106252713
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 9: 3.1693162927503256
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 10: 2.6410969106252713
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 10: 3.1693162927503256
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 11: 2.981553493670461
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 11: 3.577864192404553
# Voting Rule: r1_quadratic: Original Funds for Project 0: 3.640814654184712
# Voting Rule: r1_quadratic: Target Funds for Project 0: 4.368977585021654
# Voting Rule: r1_quadratic: Original Funds for Project 1: 2.0804107485194057
# Voting Rule: r1_quadratic: Target Funds for Project 1: 2.496492898223287
# Voting Rule: r1_quadratic: Original Funds for Project 2: 2.9347067462979566
# Voting Rule: r1_quadratic: Target Funds for Project 2: 3.521648095557548
# Voting Rule: r1_quadratic: Original Funds for Project 3: 2.566545261153662
# Voting Rule: r1_quadratic: Target Funds for Project 3: 3.079854313384394
# Voting Rule: r1_quadratic: Original Funds for Project 4: 2.1963788405003197
# Voting Rule: r1_quadratic: Target Funds for Project 4: 2.6356546086003836
# Voting Rule: r1_quadratic: Original Funds for Project 5: 2.060745339148149
# Voting Rule: r1_quadratic: Target Funds for Project 5: 2.4728944069777787
# Voting Rule: r1_quadratic: Original Funds for Project 6: 2.3880663369173143
# Voting Rule: r1_quadratic: Target Funds for Project 6: 2.865679604300777
# Voting Rule: r1_quadratic: Original Funds for Project 7: 2.2541196129272723
# Voting Rule: r1_quadratic: Target Funds for Project 7: 2.7049435355127267
# Voting Rule: r1_quadratic: Original Funds for Project 8: 1.7048033508962497
# Voting Rule: r1_quadratic: Target Funds for Project 8: 2.0457640210754997
# Voting Rule: r1_quadratic: Original Funds for Project 9: 2.5322128360912726
# Voting Rule: r1_quadratic: Target Funds for Project 9: 3.038655403309527
# Voting Rule: r1_quadratic: Original Funds for Project 10: 2.5696993116824296
# Voting Rule: r1_quadratic: Target Funds for Project 10: 3.0836391740189155
# Voting Rule: r1_quadratic: Original Funds for Project 11: 3.071496961681256
# Voting Rule: r1_quadratic: Target Funds for Project 11: 3.685796354017507
# Voting Rule: r2_mean: Original Funds for Project 0: 4.922732631825296
# Voting Rule: r2_mean: Target Funds for Project 0: 5.907279158190355
# Voting Rule: r2_mean: Original Funds for Project 1: 1.692813245224843
# Voting Rule: r2_mean: Target Funds for Project 1: 2.0313758942698117
# Voting Rule: r2_mean: Original Funds for Project 2: 3.2020030997398363
# Voting Rule: r2_mean: Target Funds for Project 2: 3.8424037196878036
# Voting Rule: r2_mean: Original Funds for Project 3: 2.481076910138376
# Voting Rule: r2_mean: Target Funds for Project 3: 2.977292292166051
# Voting Rule: r2_mean: Original Funds for Project 4: 1.8897318653161341
# Voting Rule: r2_mean: Target Funds for Project 4: 2.2676782383793608
# Voting Rule: r2_mean: Original Funds for Project 5: 1.7378128267692035
# Voting Rule: r2_mean: Target Funds for Project 5: 2.0853753921230442
# Voting Rule: r2_mean: Original Funds for Project 6: 2.1441064384331856
# Voting Rule: r2_mean: Target Funds for Project 6: 2.5729277261198225
# Voting Rule: r2_mean: Original Funds for Project 7: 2.0768626690690817
# Voting Rule: r2_mean: Target Funds for Project 7: 2.492235202882898
# Voting Rule: r2_mean: Original Funds for Project 8: 1.264458818632058
# Voting Rule: r2_mean: Target Funds for Project 8: 1.5173505823584696
# Voting Rule: r2_mean: Original Funds for Project 9: 2.454808670163248
# Voting Rule: r2_mean: Target Funds for Project 9: 2.945770404195897
# Voting Rule: r2_mean: Original Funds for Project 10: 2.5080867441811394
# Voting Rule: r2_mean: Target Funds for Project 10: 3.0097040930173673
# Voting Rule: r2_mean: Original Funds for Project 11: 3.6255060805075994
# Voting Rule: r2_mean: Target Funds for Project 11: 4.350607296609119
# Voting Rule: r3_median: Original Funds for Project 0: 4.952525131202994
# Voting Rule: r3_median: Target Funds for Project 0: 5.943030157443593
# Voting Rule: r3_median: Original Funds for Project 1: 1.7602129049287412
# Voting Rule: r3_median: Target Funds for Project 1: 2.1122554859144893
# Voting Rule: r3_median: Original Funds for Project 2: 3.496425445740382
# Voting Rule: r3_median: Target Funds for Project 2: 4.195710534888458
# Voting Rule: r3_median: Original Funds for Project 3: 2.7670573465889983
# Voting Rule: r3_median: Target Funds for Project 3: 3.3204688159067977
# Voting Rule: r3_median: Original Funds for Project 4: 2.088684415086891
# Voting Rule: r3_median: Target Funds for Project 4: 2.506421298104269
# Voting Rule: r3_median: Original Funds for Project 5: 1.6152311104479917
# Voting Rule: r3_median: Target Funds for Project 5: 1.93827733253759
# Voting Rule: r3_median: Original Funds for Project 6: 2.192537821746247
# Voting Rule: r3_median: Target Funds for Project 6: 2.631045386095496
# Voting Rule: r3_median: Original Funds for Project 7: 1.4561550032247077
# Voting Rule: r3_median: Target Funds for Project 7: 1.7473860038696492
# Voting Rule: r3_median: Original Funds for Project 8: 1.1465965029333065
# Voting Rule: r3_median: Target Funds for Project 8: 1.3759158035199677
# Voting Rule: r3_median: Original Funds for Project 9: 2.7403291558093805
# Voting Rule: r3_median: Target Funds for Project 9: 3.2883949869712565
# Voting Rule: r3_median: Original Funds for Project 10: 2.4567066062469123
# Voting Rule: r3_median: Target Funds for Project 10: 2.9480479274962947
# Voting Rule: r3_median: Original Funds for Project 11: 3.3275385560434443
# Voting Rule: r3_median: Target Funds for Project 11: 3.993046267252133
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 0: 3.6295710989970162
# Voting Rule: r4_capped_median: Target Funds for Project 0: 4.355485318796419
# Voting Rule: r4_capped_median: Original Funds for Project 1: 1.8603268648562103
# Voting Rule: r4_capped_median: Target Funds for Project 1: 2.2323922378274523
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 2: 3.593640879908901
# Voting Rule: r4_capped_median: Target Funds for Project 2: 4.312369055890681
# Voting Rule: r4_capped_median: Original Funds for Project 3: 2.92443664288761
# Voting Rule: r4_capped_median: Target Funds for Project 3: 3.5093239714651316
# Voting Rule: r4_capped_median: Original Funds for Project 4: 2.2074805375602704
# Voting Rule: r4_capped_median: Target Funds for Project 4: 2.648976645072324
# Voting Rule: r4_capped_median: Original Funds for Project 5: 1.7070990783581226
# Voting Rule: r4_capped_median: Target Funds for Project 5: 2.048518894029747
# Voting Rule: r4_capped_median: Original Funds for Project 6: 2.317240715930886
# Voting Rule: r4_capped_median: Target Funds for Project 6: 2.7806888591170633
# Voting Rule: r4_capped_median: Original Funds for Project 7: 1.5389753502593322
# Voting Rule: r4_capped_median: Target Funds for Project 7: 1.8467704203111985
# Voting Rule: r4_capped_median: Original Funds for Project 8: 1.2118103847462502
# Voting Rule: r4_capped_median: Target Funds for Project 8: 1.4541724616955003
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 9: 2.8961882581512546
# Voting Rule: r4_capped_median: Target Funds for Project 9: 3.4754259097815052
# Voting Rule: r4_capped_median: Original Funds for Project 10: 2.596434377837877
# Voting Rule: r4_capped_median: Target Funds for Project 10: 3.1157212534054524
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 11: 3.5167958105062667
# Voting Rule: r4_capped_median: Target Funds for Project 11: 4.22015497260752
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 0: 1.8615045911241275
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 0: 2.233805509348953
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 1: 2.0524556620797765
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 1: 2.4629467944957315
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 2: 3.528288002003442
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 2: 4.23394560240413
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 3: 2.7774634296940572
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 3: 3.3329561156328684
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 4: 5.45045748406393
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 4: 6.540548980876716
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 5: 1.591963430310599
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 5: 1.9103561163727187
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 6: 0.9145643393810785
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 6: 1.0974772072572943
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 7: 1.828818775949354
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 7: 2.1945825311392246
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 8: 2.378001492913876
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 8: 2.853601791496651
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 9: 0.907422230163273
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 9: 1.0889066761959274
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 10: 1.853350354447809
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 10: 2.2240204253373705
# No voters left in the matrix. Cannot proceed.
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 11: 4.855710207868678
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 11: 5.826852249442413
# Voting Rule: r1_quadratic: Original Funds for Project 0: 2.349626800322865
# Voting Rule: r1_quadratic: Target Funds for Project 0: 2.819552160387438
# Voting Rule: r1_quadratic: Original Funds for Project 1: 2.320613783722244
# Voting Rule: r1_quadratic: Target Funds for Project 1: 2.7847365404666924
# Voting Rule: r1_quadratic: Original Funds for Project 2: 3.1061838820899954
# Voting Rule: r1_quadratic: Target Funds for Project 2: 3.7274206585079943
# Voting Rule: r1_quadratic: Original Funds for Project 3: 2.872208480466123
# Voting Rule: r1_quadratic: Target Funds for Project 3: 3.4466501765593476
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r1_quadratic: Original Funds for Project 4: 3.884352685520869
# Voting Rule: r1_quadratic: Target Funds for Project 4: 4.6612232226250425
# Voting Rule: r1_quadratic: Original Funds for Project 5: 1.935873661975171
# Voting Rule: r1_quadratic: Target Funds for Project 5: 2.3230483943702054
# Voting Rule: r1_quadratic: Original Funds for Project 6: 1.6088958413301244
# Voting Rule: r1_quadratic: Target Funds for Project 6: 1.9306750095961491
# Voting Rule: r1_quadratic: Original Funds for Project 7: 2.2088099808093244
# Voting Rule: r1_quadratic: Target Funds for Project 7: 2.650571976971189
# Voting Rule: r1_quadratic: Original Funds for Project 8: 2.4391980829453996
# Voting Rule: r1_quadratic: Target Funds for Project 8: 2.9270376995344796
# Voting Rule: r1_quadratic: Original Funds for Project 9: 1.5715317401493503
# Voting Rule: r1_quadratic: Target Funds for Project 9: 1.8858380881792203
# Voting Rule: r1_quadratic: Original Funds for Project 10: 2.024186610150362
# Voting Rule: r1_quadratic: Target Funds for Project 10: 2.4290239321804346
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r1_quadratic: Original Funds for Project 11: 3.6785184505181694
# Voting Rule: r1_quadratic: Target Funds for Project 11: 4.414222140621803
# Voting Rule: r2_mean: Original Funds for Project 0: 2.0939316149354394
# Voting Rule: r2_mean: Target Funds for Project 0: 2.512717937922527
# Voting Rule: r2_mean: Original Funds for Project 1: 2.010644923593654
# Voting Rule: r2_mean: Target Funds for Project 1: 2.412773908312385
# Voting Rule: r2_mean: Original Funds for Project 2: 3.464889348128313
# Voting Rule: r2_mean: Target Funds for Project 2: 4.157867217753975
# Voting Rule: r2_mean: Original Funds for Project 3: 2.9594068659270243
# Voting Rule: r2_mean: Target Funds for Project 3: 3.551288239112429
# Voting Rule: r2_mean: Original Funds for Project 4: 5.3626268228349
# Voting Rule: r2_mean: Target Funds for Project 4: 6.43515218740188
# Voting Rule: r2_mean: Original Funds for Project 5: 1.3877760731704638
# Voting Rule: r2_mean: Target Funds for Project 5: 1.6653312878045565
# Voting Rule: r2_mean: Original Funds for Project 6: 1.013375449679821
# Voting Rule: r2_mean: Target Funds for Project 6: 1.2160505396157852
# Voting Rule: r2_mean: Original Funds for Project 7: 1.8359442042788494
# Voting Rule: r2_mean: Target Funds for Project 7: 2.2031330451346194
# Voting Rule: r2_mean: Original Funds for Project 8: 2.30513659568695
# Voting Rule: r2_mean: Target Funds for Project 8: 2.76616391482434
# Voting Rule: r2_mean: Original Funds for Project 9: 1.1836801566865292
# Voting Rule: r2_mean: Target Funds for Project 9: 1.4204161880238348
# Voting Rule: r2_mean: Original Funds for Project 10: 1.5986481664794085
# Voting Rule: r2_mean: Target Funds for Project 10: 1.9183777997752902
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r2_mean: Original Funds for Project 11: 4.783939778598644
# Voting Rule: r2_mean: Target Funds for Project 11: 5.740727734318373
# Voting Rule: r3_median: Original Funds for Project 0: 1.8401048680862786
# Voting Rule: r3_median: Target Funds for Project 0: 2.2081258417035343
# Voting Rule: r3_median: Original Funds for Project 1: 1.7897943441550288
# Voting Rule: r3_median: Target Funds for Project 1: 2.1477532129860344
# Voting Rule: r3_median: Original Funds for Project 2: 3.7815840083510857
# Voting Rule: r3_median: Target Funds for Project 2: 4.537900810021303
# Voting Rule: r3_median: Original Funds for Project 3: 3.0058300812567453
# Voting Rule: r3_median: Target Funds for Project 3: 3.606996097508094
# Voting Rule: r3_median: Original Funds for Project 4: 5.6603257968126846
# Voting Rule: r3_median: Target Funds for Project 4: 6.792390956175221
# Voting Rule: r3_median: Original Funds for Project 5: 1.5537749105194516
# Voting Rule: r3_median: Target Funds for Project 5: 1.8645298926233418
# Voting Rule: r3_median: Original Funds for Project 6: 0.7861720059010588
# Voting Rule: r3_median: Target Funds for Project 6: 0.9434064070812705
# Voting Rule: r3_median: Original Funds for Project 7: 1.8191765094820758
# Voting Rule: r3_median: Target Funds for Project 7: 2.1830118113784907
# Voting Rule: r3_median: Original Funds for Project 8: 1.9470391774237243
# Voting Rule: r3_median: Target Funds for Project 8: 2.336447012908469
# Voting Rule: r3_median: Original Funds for Project 9: 0.8706494931990327
# Voting Rule: r3_median: Target Funds for Project 9: 1.0447793918388393
# Voting Rule: r3_median: Original Funds for Project 10: 1.7195915672946636
# Voting Rule: r3_median: Target Funds for Project 10: 2.063509880753596
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r3_median: Original Funds for Project 11: 5.225957237518172
# Voting Rule: r3_median: Target Funds for Project 11: 6.271148685021807
# Voting Rule: r4_capped_median: Original Funds for Project 0: 2.1964498083241577
# Voting Rule: r4_capped_median: Target Funds for Project 0: 2.635739769988989
# Voting Rule: r4_capped_median: Original Funds for Project 1: 2.13639641541052
# Voting Rule: r4_capped_median: Target Funds for Project 1: 2.563675698492624
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 2: 3.8995758558178837
# Voting Rule: r4_capped_median: Target Funds for Project 2: 4.67949102698146
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 3: 3.5879231778228218
# Voting Rule: r4_capped_median: Target Funds for Project 3: 4.305507813387386
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 4: 3.8995758558178837
# Voting Rule: r4_capped_median: Target Funds for Project 4: 4.67949102698146
# Voting Rule: r4_capped_median: Original Funds for Project 5: 1.8546707112071594
# Voting Rule: r4_capped_median: Target Funds for Project 5: 2.225604853448591
# Voting Rule: r4_capped_median: Original Funds for Project 6: 0.9384179030334666
# Voting Rule: r4_capped_median: Target Funds for Project 6: 1.12610148364016
# Voting Rule: r4_capped_median: Original Funds for Project 7: 2.171468574894485
# Voting Rule: r4_capped_median: Target Funds for Project 7: 2.6057622898733817
# Voting Rule: r4_capped_median: Original Funds for Project 8: 2.3240924483285728
# Voting Rule: r4_capped_median: Target Funds for Project 8: 2.788910937994287
# Voting Rule: r4_capped_median: Original Funds for Project 9: 1.039254852058179
# Voting Rule: r4_capped_median: Target Funds for Project 9: 1.2471058224698148
# Voting Rule: r4_capped_median: Original Funds for Project 10: 2.0525985414669887
# Voting Rule: r4_capped_median: Target Funds for Project 10: 2.4631182497603863
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 11: 3.8995758558178837
# Voting Rule: r4_capped_median: Target Funds for Project 11: 4.67949102698146
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 0: 2.3108130294552796
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 0: 2.7729756353463353
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 1: 1.417269057272651
# ...
# Voting Rule: r4_capped_median: Target Funds for Project 1: 4.663498851462045
# Voting Rule: r4_capped_median: Original Funds for Project 2: 1.0774571130970567
# Voting Rule: r4_capped_median: Target Funds for Project 2: 1.292948535716468
# Voting Rule: r4_capped_median: Original Funds for Project 3: 1.3557666252434788
# Voting Rule: r4_capped_median: Target Funds for Project 3: 1.6269199502921745
# Voting Rule: r4_capped_median: Original Funds for Project 4: 2.8601334734542325
# Voting Rule: r4_capped_median: Target Funds for Project 4: 3.432160168145079
# Voting Rule: r4_capped_median: Original Funds for Project 5: 2.463014153936753
# Voting Rule: r4_capped_median: Target Funds for Project 5: 2.9556169847241036
# Voting Rule: r4_capped_median: Original Funds for Project 6: 2.7968177083333012
# Voting Rule: r4_capped_median: Target Funds for Project 6: 3.3561812499999615
# Voting Rule: r4_capped_median: Original Funds for Project 7: 2.036162315592048
# Voting Rule: r4_capped_median: Target Funds for Project 7: 2.4433947787104575
# Voting Rule: r4_capped_median: Original Funds for Project 8: 2.819151389711762
# Voting Rule: r4_capped_median: Target Funds for Project 8: 3.3829816676541147
# Voting Rule: r4_capped_median: Original Funds for Project 9: 2.8998215163930885
# Voting Rule: r4_capped_median: Target Funds for Project 9: 3.479785819671706
# Voting Rule: r4_capped_median: Original Funds for Project 10: 2.372495403184417
# Voting Rule: r4_capped_median: Target Funds for Project 10: 2.8469944838213004
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 11: 3.8862490428850376
# Voting Rule: r4_capped_median: Target Funds for Project 11: 4.663498851462045
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 0: 1.1038842417619128
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 0: 1.3246610901142952
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 1: 2.539531602660505
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 1: 3.047437923192606
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 2: 1.2924279159219587
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 2: 1.5509134991063505
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 3: 3.893124528993009
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 3: 4.671749434791611
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 4: 2.56125802258599
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 4: 3.073509627103188
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 5: 3.3899870361497313
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 5: 4.067984443379677
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 6: 2.093335451704674
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 6: 2.5120025420456087
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 7: 2.093335451704674
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 7: 2.5120025420456087
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 8: 2.4532361953527557
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 8: 2.9438834344233067
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 9: 5.1801436874302835
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 9: 6.21617242491634
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 10: 1.3064004140298318
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 10: 1.567680496835798
# Voting Rule: majoritarian_moving_phantoms: Original Funds for Project 11: 2.093335451704674
# Voting Rule: majoritarian_moving_phantoms: Target Funds for Project 11: 2.5120025420456087
# Voting Rule: r1_quadratic: Original Funds for Project 0: 1.6037944523739824
# Voting Rule: r1_quadratic: Target Funds for Project 0: 1.9245533428487789
# Voting Rule: r1_quadratic: Original Funds for Project 1: 2.6894720720242575
# Voting Rule: r1_quadratic: Target Funds for Project 1: 3.227366486429109
# Voting Rule: r1_quadratic: Original Funds for Project 2: 1.8714280488433057
# Voting Rule: r1_quadratic: Target Funds for Project 2: 2.2457136586119666
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r1_quadratic: Original Funds for Project 3: 3.3281098752036544
# Voting Rule: r1_quadratic: Target Funds for Project 3: 3.993731850244385
# Voting Rule: r1_quadratic: Original Funds for Project 4: 2.411832954898422
# Voting Rule: r1_quadratic: Target Funds for Project 4: 2.8941995458781062
# Voting Rule: r1_quadratic: Original Funds for Project 5: 2.8982526127837502
# Voting Rule: r1_quadratic: Target Funds for Project 5: 3.4779031353405
# Voting Rule: r1_quadratic: Original Funds for Project 6: 2.280975617039487
# Voting Rule: r1_quadratic: Target Funds for Project 6: 2.737170740447384
# Voting Rule: r1_quadratic: Original Funds for Project 7: 2.2175175626019197
# Voting Rule: r1_quadratic: Target Funds for Project 7: 2.6610210751223033
# Voting Rule: r1_quadratic: Original Funds for Project 8: 2.62026804102448
# Voting Rule: r1_quadratic: Target Funds for Project 8: 3.144321649229376
# Voting Rule: r1_quadratic: Original Funds for Project 9: 3.9118097295600234
# Voting Rule: r1_quadratic: Target Funds for Project 9: 4.6941716754720275
# Voting Rule: r1_quadratic: Original Funds for Project 10: 1.7744130762539518
# Voting Rule: r1_quadratic: Target Funds for Project 10: 2.1292956915047423
# Voting Rule: r1_quadratic: Original Funds for Project 11: 2.392125957392762
# Voting Rule: r1_quadratic: Target Funds for Project 11: 2.8705511488713142
# Voting Rule: r2_mean: Original Funds for Project 0: 1.0189642832319241
# Voting Rule: r2_mean: Target Funds for Project 0: 1.2227571398783088
# Voting Rule: r2_mean: Original Funds for Project 1: 2.850618194988993
# Voting Rule: r2_mean: Target Funds for Project 1: 3.420741833986791
# Voting Rule: r2_mean: Original Funds for Project 2: 1.3234210850976842
# Voting Rule: r2_mean: Target Funds for Project 2: 1.588105302117221
# Voting Rule: r2_mean: Original Funds for Project 3: 4.011639709161802
# Voting Rule: r2_mean: Target Funds for Project 3: 4.8139676509941625
# Voting Rule: r2_mean: Original Funds for Project 4: 2.396547616305156
# Voting Rule: r2_mean: Target Funds for Project 4: 2.875857139566187
# Voting Rule: r2_mean: Original Funds for Project 5: 3.100735999337505
# Voting Rule: r2_mean: Target Funds for Project 5: 3.720883199205006
# Voting Rule: r2_mean: Original Funds for Project 6: 2.01445350722872
# Voting Rule: r2_mean: Target Funds for Project 6: 2.417344208674464
# Voting Rule: r2_mean: Original Funds for Project 7: 1.8977945493122188
# Voting Rule: r2_mean: Target Funds for Project 7: 2.2773534591746625
# Voting Rule: r2_mean: Original Funds for Project 8: 2.491258266451549
# Voting Rule: r2_mean: Target Funds for Project 8: 2.9895099197418586
# Voting Rule: r2_mean: Original Funds for Project 9: 5.580394860707694
# Voting Rule: r2_mean: Target Funds for Project 9: 6.696473832849232
# Voting Rule: r2_mean: Original Funds for Project 10: 1.2235735135806713
# Voting Rule: r2_mean: Target Funds for Project 10: 1.4682882162968056
# Voting Rule: r2_mean: Original Funds for Project 11: 2.0905984145960828
# Voting Rule: r2_mean: Target Funds for Project 11: 2.5087180975152994
# Voting Rule: r3_median: Original Funds for Project 0: 0.8459095246796982
# Voting Rule: r3_median: Target Funds for Project 0: 1.0150914296156377
# Voting Rule: r3_median: Original Funds for Project 1: 2.408428729651882
# Voting Rule: r3_median: Target Funds for Project 1: 2.890114475582258
# Voting Rule: r3_median: Original Funds for Project 2: 1.416091477597669
# Voting Rule: r3_median: Target Funds for Project 2: 1.6993097731172027
# Voting Rule: r3_median: Original Funds for Project 3: 4.172819695597896
# Voting Rule: r3_median: Target Funds for Project 3: 5.007383634717475
# Voting Rule: r3_median: Original Funds for Project 4: 2.598069295180947
# Voting Rule: r3_median: Target Funds for Project 4: 3.1176831542171364
# Voting Rule: r3_median: Original Funds for Project 5: 3.6482412820481858
# Voting Rule: r3_median: Target Funds for Project 5: 4.377889538457823
# Voting Rule: r3_median: Original Funds for Project 6: 1.817855966200653
# Voting Rule: r3_median: Target Funds for Project 6: 2.1814271594407835
# Voting Rule: r3_median: Original Funds for Project 7: 1.5178327937178466
# Voting Rule: r3_median: Target Funds for Project 7: 1.8213993524614158
# Voting Rule: r3_median: Original Funds for Project 8: 2.6268420844957547
# Voting Rule: r3_median: Target Funds for Project 8: 3.1522105013949058
# Voting Rule: r3_median: Original Funds for Project 9: 5.605193759479317
# Voting Rule: r3_median: Target Funds for Project 9: 6.72623251137518
# Voting Rule: r3_median: Original Funds for Project 10: 1.2928212779849726
# Voting Rule: r3_median: Target Funds for Project 10: 1.551385533581967
# Voting Rule: r3_median: Original Funds for Project 11: 2.0498941133651787
# Voting Rule: r3_median: Target Funds for Project 11: 2.4598729360382143
# Voting Rule: r4_capped_median: Original Funds for Project 0: 0.9541148540754292
# Voting Rule: r4_capped_median: Target Funds for Project 0: 1.1449378248905149
# Voting Rule: r4_capped_median: Original Funds for Project 1: 2.716505204044106
# Voting Rule: r4_capped_median: Target Funds for Project 1: 3.259806244852927
# Voting Rule: r4_capped_median: Original Funds for Project 2: 1.5972321791945243
# Voting Rule: r4_capped_median: Target Funds for Project 2: 1.9166786150334292
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 3: 3.7687360639194485
# Voting Rule: r4_capped_median: Target Funds for Project 3: 4.522483276703338
# Voting Rule: r4_capped_median: Original Funds for Project 4: 2.9304038246738457
# Voting Rule: r4_capped_median: Target Funds for Project 4: 3.516484589608615
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 5: 3.7687360639194485
# Voting Rule: r4_capped_median: Target Funds for Project 5: 4.522483276703338
# Voting Rule: r4_capped_median: Original Funds for Project 6: 2.050388758275807
# Voting Rule: r4_capped_median: Target Funds for Project 6: 2.4604665099309684
# Voting Rule: r4_capped_median: Original Funds for Project 7: 1.7119878334947898
# Voting Rule: r4_capped_median: Target Funds for Project 7: 2.054385400193748
# Voting Rule: r4_capped_median: Original Funds for Project 8: 2.9628571129718293
# Voting Rule: r4_capped_median: Target Funds for Project 8: 3.555428535566195
# No voters left in the matrix. Cannot proceed.
# Voting Rule: r4_capped_median: Original Funds for Project 9: 3.7687360639194485
# Voting Rule: r4_capped_median: Target Funds for Project 9: 4.522483276703338
# Voting Rule: r4_capped_median: Original Funds for Project 10: 1.4581937535900236
# Voting Rule: r4_capped_median: Target Funds for Project 10: 1.7498325043080283
# Voting Rule: r4_capped_median: Original Funds for Project 11: 2.3121082879213013
# Voting Rule: r4_capped_median: Target Funds for Project 11: 2.7745299455055616
# Control Results:
#     round  desired_increase  majoritarian_moving_phantoms_min_removal_cost  \
# 0       1                20                                              2
# 1       2                20                                              1
# 2       3                20                                              1
# 3       4                20                                              1
# 4       5                20                                              2
# ..    ...               ...                                            ...
# 95     96                20                                              1
# 96     97                20                                              1
# 97     98                20                                              2
# 98     99                20                                              1
# 99    100                20                                              2
#
#     majoritarian_moving_phantoms_min_addition_cost  \
# 0                                                2
# 1                                                1
# 2                                                1
# 3                                                1
# 4                                                1
# ..                                             ...
# 95                                               1
# 96                                               1
# 97                                               2
# 98                                               1
# 99                                               1
#
#     r1_quadratic_min_removal_cost  r1_quadratic_min_addition_cost  \
# 0                               4                               1
# 1                               3                               1
# 2                               3                               1
# 3                               4                               1
# 4                               2                               1
# ..                            ...                             ...
# 95                              4                               1
# 96                              3                               1
# 97                              3                               1
# 98                              4                               1
# 99                              3                               1
#
#     r2_mean_min_removal_cost  r2_mean_min_addition_cost  \
# 0                          3                          1
# 1                          2                          1
# 2                          2                          1
# 3                          3                          1
# 4                          2                          1
# ..                       ...                        ...
# 95                         3                          1
# 96                         2                          1
# 97                         2                          1
# 98                         3                          1
# 99                         2                          1
#
#     r3_median_min_removal_cost  r3_median_min_addition_cost  \
# 0                            2                            2
# 1                            2                            2
# 2                            1                            1
# 3                            1                            1
# 4                            2                            2
# ..                         ...                          ...
# 95                           2                            2
# 96                           1                            1
# 97                           1                            1
# 98                           2                            2
# 99                           2                            2
#
#     r4_capped_median_min_removal_cost  r4_capped_median_min_addition_cost
# 0                                   2                                   2
# 1                                   2                                   2
# 2                                   1                                   1
# 3                                   1                                   1
# 4                                   2                                   2
# ..                                ...                                 ...
# 95                                  2                                   2
# 96                                  1                                   1
# 97                                  1                                   1
# 98                                  2                                   1
# 99                                  2                                   2
#
# [100 rows x 12 columns]

# %% [markdown]
# # Evaluate Robustness

# %%
robustness_results = eval_metrics.evaluate_robustness(num_rounds)
robustness_results.to_csv(os.path.join(output_dir,'robustness_results.csv'), index=False)
print("Robustness Results:")
robustness_results.head(100)
# Out:
# Robustness Results:
#     majoritarian_moving_phantoms_distances  r1_quadratic_distances  \
# 0                             1.198283e+04           104303.709290
# 1                             1.938420e+04            78164.242473
# 2                             5.451881e+03            94527.995858
# 3                             1.955073e+04            78053.084928
# 4                             2.831638e+06            82914.887763
# ..                                     ...                     ...
# 95                            1.320736e+04            90405.716232
# 96                            2.810549e+04            96393.566139
# 97                            8.375985e+03            79435.268908
# 98                            2.437716e+04            97992.934741
# 99                            2.883655e+04            93692.001762
#
#     r2_mean_distances  r3_median_distances  r4_capped_median_distances  \
# 0        1.041542e+06         42389.202298                42389.202298
# 1        6.726732e+05          9195.861420                 9195.861420
# 2        9.815502e+05          4388.631727                 4388.631727
# 3        6.753128e+05          2477.823582                 2477.823582
# 4        7.613558e+05         26278.525115                26278.525115
# ..                ...                  ...                         ...
# 95       8.772402e+05          5748.820026                 5748.820026
# 96       9.519272e+05         13230.623482                13230.623482
# 97       7.863450e+05          7001.784781                 7001.784781
# 98       1.018374e+06         17193.041149                17193.041149
# 99       9.256479e+05         15546.285521                15546.285521
#
#     changed_vote_l1_distances  round
# 0                  53939480.0      1
# 1                  34587737.0      2
# 2                  50752952.0      3
# 3                  34739501.0      4
# 4                  39207831.0      5
# ..                        ...    ...
# 95                 45278261.0     96
# 96                 49237696.0     97
# 97                 40541694.0     98
# 98                 52686044.0     99
# 99                 47835305.0    100
#
# [100 rows x 7 columns]

# %%
print(f"Avg Mean L1 Distance: {np.mean(robustness_results['r1_quadratic_distances'])}")
print(f"Avg Median L1 Distance: {np.mean(robustness_results['r2_mean_distances'])}")
print(f"Avg Quadratic L1 Distance: {np.mean(robustness_results['r3_median_distances'])}")
print(f"Avg Majortarian L1 Distance: {np.mean(robustness_results['majoritarian_moving_phantoms_distances'])}")
print(f"Avg R4 capped median L1 Distance: {np.mean(robustness_results['r4_capped_median_distances'])}")
# Out:
# Avg Mean L1 Distance: 93497.11186647613
# Avg Median L1 Distance: 914731.7114574165
# Avg Quadratic L1 Distance: 13004.755443783284
# Avg Majortarian L1 Distance: 43070.48986803379
# Avg R4 capped median L1 Distance: 13004.755443782175

# %%
import matplotlib.pyplot as plt
import pandas as pd

def plot_robustness_ordered(robustness_df):
    """Plot the relationship between vote changes and outcome changes after ordering by vote change."""
    # Replace 0 values with the column mean in the specified columns
    columns_to_replace = [
        'majoritarian_moving_phantoms_distances', 
        'r1_quadratic_distances', 
        'r2_mean_distances', 
        'r3_median_distances',
        'r4_capped_median_distances'
    ]
   

    # Sort by changed_vote_l1_distances
    robustness_df = robustness_df.sort_values(by='changed_vote_l1_distances').reset_index(drop=True)

    # Plot each voting rule's outcome change against the changed vote L1 distance
    plt.figure(figsize=(12, 8))
    
    for method in columns_to_replace:
        plt.plot(robustness_df['changed_vote_l1_distances'], robustness_df[method], label=method)

    plt.xlabel('Change in Votes (L1 Distance)')
    plt.ylabel('Change in Outcome (L1 Distance)')
    plt.title('Relationship Between Vote Changes and Outcome Changes')
    plt.legend()
    plt.grid(True)
    plt.show()

# Assuming robustness_df is your DataFrame with the results
plot_robustness_ordered(robustness_results)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter

def plot_robustness_ordered(robustness_df, window_length=100, polyorder=2):
    """Plot the relationship between vote changes and outcome changes after applying Savitzky-Golay smoothing."""
    # Replace 0 values with the column mean in the specified columns
    columns_to_replace = [
        'majoritarian_moving_phantoms_distances', 
        'r1_quadratic_distances', 
        'r2_mean_distances', 
        'r3_median_distances'
    ]
   
    # Sort by changed_vote_l1_distances
    robustness_df = robustness_df.sort_values(by='changed_vote_l1_distances').reset_index(drop=True)

    # Apply smoothing to the voting rule columns using Savitzky-Golay filter
    smoothed_results = {}
    
    for method in columns_to_replace:
        smoothed_results[method] = savgol_filter(robustness_df[method], window_length=window_length, polyorder=polyorder)

    # Plot each voting rule's outcome change against the smoothed changed vote L1 distance
    plt.figure(figsize=(12, 8))
    
    for method in columns_to_replace:
        plt.plot(robustness_df['changed_vote_l1_distances'], smoothed_results[method], label=f"{method} (smoothed)")

    plt.xlabel('Change in Votes (L1 Distance)')
    plt.ylabel('Change in Outcome (L1 Distance)')
    plt.title('Smoothed Relationship Between Vote Changes and Outcome Changes')
    plt.legend()
    plt.grid(True)
    plt.show()

# Assuming robustness_df is your DataFrame with the results
plot_robustness_ordered(robustness_results)

# %% [markdown]
# # Evaluate Bribery Cost

# %%
#bribery_results = eval_metrics.evaluate_bribery(num_rounds)
bribery_constant_desired_increase_results = eval_metrics.evaluate_bribery(num_rounds,1)
bribery_constant_desired_increase_results.to_csv(os.path.join(output_dir, 'bribery_constant_desired_increase_results.csv'), index=False)
print("Bribery Cost Results:")
bribery_constant_desired_increase_results.head(100)
# Out:
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# ...
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 2 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 8 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 0 and voting rule r4_capped_median, the bribery cost is infinite
# For project 1 and voting rule r4_capped_median, the bribery cost is infinite
# For project 3 and voting rule r4_capped_median, the bribery cost is infinite
# For project 4 and voting rule r4_capped_median, the bribery cost is infinite
# For project 5 and voting rule r4_capped_median, the bribery cost is infinite
# For project 6 and voting rule r4_capped_median, the bribery cost is infinite
# For project 7 and voting rule r4_capped_median, the bribery cost is infinite
# For project 9 and voting rule r4_capped_median, the bribery cost is infinite
# For project 10 and voting rule r4_capped_median, the bribery cost is infinite
# For project 11 and voting rule r4_capped_median, the bribery cost is infinite
# Bribery Cost Results:
#     round  desired_increase  majoritarian_moving_phantoms_bribery_cost  \
# 0       1                 1                                   1.252263
# 1       2                 1                                   0.864790
# 2       3                 1                                   1.483198
# 3       4                 1                                   1.937719
# 4       5                 1                                   1.073092
# ..    ...               ...                                        ...
# 95     96                 1                                   0.889719
# 96     97                 1                                   1.599556
# 97     98                 1                                   1.166922
# 98     99                 1                                   1.106069
# 99    100                 1                                   1.469075
#
#     r1_quadratic_bribery_cost  r2_mean_bribery_cost  r3_median_bribery_cost  \
# 0                    2.793509              1.059607                0.770623
# 1                    2.044048              0.864790                0.707555
# 2                    4.719267              1.483198                1.232199
# 3                    3.629006              1.287712                1.053582
# 4                    2.633952              1.073092                0.780430
# ..                        ...                   ...                     ...
# 95                   2.588273              0.889719                0.727952
# 96                   3.851449              1.366643                1.118162
# 97                   3.500765              1.303674                0.907606
# 98                   3.710121              1.316495                0.967811
# 99                   4.407224              1.469075                1.335522
#
#     r4_capped_median_bribery_cost
# 0                        0.770623
# 1                        0.707555
# 2                        1.232199
# 3                        1.053582
# 4                        0.877984
# ..                            ...
# 95                       0.727952
# 96                       1.118162
# 97                       0.907606
# 98                       0.967811
# 99                       1.335522
#
# [100 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# Plot the results with a logarithmic y-axis
def plot_bribery_costs(df):
    plt.figure(figsize=(14, 8))

    # Plot mean bribery cost
    plt.plot(df['round'], df['r2_mean_bribery_cost'], label='Mean Bribery Cost')

    plt.plot(df['round'], df['r4_capped_median_bribery_cost'], label='R4 Capped Median Bribery Cost')
    plt.plot(df['round'], df['majoritarian_moving_phantoms_bribery_cost'], label='Phantoms Bribery Cost')

    # Plot median bribery cost
    plt.plot(df['round'], df['r3_median_bribery_cost'], label='Median Bribery Cost')

    # Plot quadratic bribery cost
    plt.plot(df['round'], df['r1_quadratic_bribery_cost'], label='Quadratic Bribery Cost')

    plt.xlabel('Round')
    plt.ylabel('Bribery Cost (log scale)')
    plt.yscale('log')
    plt.title('Bribery Costs Over Multiple Rounds')
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot the bribery costs
plot_bribery_costs(bribery_constant_desired_increase_results)

# %%
summary_stats = bribery_constant_desired_increase_results[['r1_quadratic_bribery_cost', 'r2_mean_bribery_cost', 'r3_median_bribery_cost',"majoritarian_moving_phantoms_bribery_cost",'r4_capped_median_bribery_cost']].describe()
print(summary_stats)
# Out:
#        r1_quadratic_bribery_cost  r2_mean_bribery_cost  \
# count                 100.000000            100.000000
# mean                    3.239740              1.193338
# std                     0.729320              0.240679
# min                     1.580524              0.579525
# 25%                     2.737229              1.041685
# 50%                     3.270137              1.192003
# 75%                     3.795607              1.361957
# max                     4.825523              1.918288
#
#        r3_median_bribery_cost  majoritarian_moving_phantoms_bribery_cost  \
# count              100.000000                                 100.000000
# mean                 0.926907                                   1.314827
# std                  0.259908                                   0.358477
# min                  0.354564                                   0.568134
# 25%                  0.749265                                   1.059962
# 50%                  0.925803                                   1.280502
# 75%                  1.118329                                   1.595392
# max                  1.712161                                   2.109510
#
#        r4_capped_median_bribery_cost
# count                     100.000000
# mean                        0.937635
# std                         0.268152
# min                         0.354564
# 25%                         0.749265
# 50%                         0.942004
# 75%                         1.118329
# max                         1.883377

# %% [markdown]
# # VEV

# %%
vev_results = eval_metrics.evaluate_vev()
vev_results.to_csv(os.path.join(output_dir, 'vev_results.csv'), index=False)

vev_results.head(100)
# Out:
#     round                   voting_rule   max_vev
# 0       1  majoritarian_moving_phantoms  4.317496
# 1       1                  r1_quadratic  2.032121
# 2       1                       r2_mean  5.900654
# 3       1                     r3_median  3.163268
# 4       1              r4_capped_median  3.272974
# ..    ...                           ...       ...
# 95     20  majoritarian_moving_phantoms  2.847077
# 96     20                  r1_quadratic  2.171136
# 97     20                       r2_mean  5.927716
# 98     20                     r3_median  2.726122
# 99     20              r4_capped_median  2.991505
#
# [100 rows x 3 columns]
